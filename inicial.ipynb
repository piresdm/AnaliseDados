# %% [markdown]
# # Python Insights - Analisando Dados com Python
#
# ### Case - Cancelamento de Clientes
#
# Você foi contratado por uma empresa com mais de 800 mil clientes para um projeto de Dados. Recentemente a empresa percebeu que da sua base total de clientes, a maioria são clientes inativos, ou seja, que já cancelaram o serviço.
#
# Precisando melhorar seus resultados ela quer conseguir entender os principais motivos desses cancelamentos e quais as ações mais eficientes para reduzir esse número.
#
# Base de dados e arquivos: https://drive.google.com/drive/folders/1uDesZePdkhiraJmiyeZ-w5tfc8XsNYFZ?usp=drive_link

# %%
import pandas as pd

tabela = pd.read_csv('cancelamentos.csv')
#print(tabela) # Imprime a tabela
#display(tabela) # Mostra a tabela com uma formatação bem melhor. Só funciona para arquivos ipynb
#display (tabela.info()) # Mostra as informações da tabela, como a quantidade em cada e os tipos de dado
    #Você pode precisar disso para tratar os dados, ex: mudar o tipo de algum dado de float para int
    # Os dados do tipo string são apresentados como object
#tabela = tabela.drop(columns='CustomerID') 
    # Exclui da tabela o que você pedir, ele vai fazer aqui as edições e no final
    # você pode fazer a exportação sem ter que alterar o arquivo de origem 
#tabela = tabela.drop(columns=['CustomerID','sexo'])
    #Se quiser fazer mais de uma exclusão ao mesmo tempo, bota os nomes entre [], que vira lista
#display(tabela) # Depois que você alterar a tabela, você tem que dar o display de novo
#tabela = tabela.drop_duplicates() #Exclui valores duplicadas da base.
    #A mágica daqui é que você não precisa definir quais são as linhas, ele vai ver quais são e excluir
#tabela = tabela.dropna() #É para apagar as linhas com valores vazios. 
    #Significa Not a Number, ele procura onde está vazio e apaga
#display(tabela.info())
#display(tabela['cancelou'].value_counts())
    #Traz a quantidade de cada tipo da coluna. 
    # Ex: X clientes cancelaram e Y não. Nesse caso X é 1 e Y é 0
#display(tabela['cancelou'].value_counts(normalize=True))
    # Normalize true transforma a informação para %. 
#display(tabela['cancelou'].value_counts(normalize=True).map('{:.1%}'.format))
    # O 1 significa que é 1 casa decimal
    #Só recomenda fazer a formatação no final do projeto, porque depois que formata não consegue usar em outros cálculos

#GRÁFICOS 

import plotly.express as px # O express tem gráficos melhores que o básico
    # A criação do gráfico sempre tem 2 etapas: criação e exibição

#grafico = px.histogram(tabela, x='duracao_contrato', color='cancelou', text_auto=True) 
    # Tem que passar 2 infos: a tabela analisada e o eixo x, que é a informação que você quer ver.
    # O eixo Y já vai ser a quantidade do item principal, nesse caso a quantidade de clientes
    # O color é o que coloca as cores diferentes
    # Text_auto coloca os rótulos no gráfico
#grafico.show() #Para mostrar o gráfico

#print(tabela.columns) #Traz uma lista das colunas da tabela
    #Para criar um gráfico para cada coluna da tabela, basta fazer um for nessa lista
    #No for do python, é a identação que mostra o que você tem que rodar dentro do for
#for coluna in tabela.columns: 
    #grafico = px.histogram(tabela, x=coluna, color='cancelou', text_auto=True)
    #grafico.show()

# Filtrando bases para gerar gráficos
# Ex: Tenho um cancelamento X, se eu resolver o problema dos cancelamentos dos clientes mensais,
# qual vai ser a minha nova taxa de cancelamento?
condicao = tabela['duracao_contrato'] != 'Monthly' #Define a condição que você quer filtrar
tabela = tabela[condicao] #Retira a condição escolhida dos números da tabela, ou seja, filtra
#display(tabela['cancelou'].value_counts(normalize=True)) #Exibe o novo percentual
    # Se quiser fazer várias condições, você faz uma por uma e coloca o display no final
    # Pode usar a mesma variável, não tem problema desde que você já coloque abaixo a formação da nova tabela,
    # Porque aí a partir da segunda vez quando ele puxar a mesma variável,
    # ele já vai estar usando a tabela após o filtro, então você pode substituir o valor da variável de novo
    # Se você colocar as 3 condições e depois a tabela receber, vai dar erro, então é condição, tabela, condição, tabela,etc...

#Filtro 2 
condicao = tabela['ligacoes_callcenter'] <= 4
tabela = tabela[condicao]

#Filtro 3
tabela = tabela[tabela['dias_atraso'] <= 20]# Maneira simplificada

# % após os 3 filtros
display(tabela['cancelou'].value_counts(normalize=True))
# Out:
# cancelou
# 0.0    0.816452
# 1.0    0.183548
# Name: proportion, dtype: float64
